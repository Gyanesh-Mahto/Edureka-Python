# %%
import ipywidgets as widgets
from ipywidgets import HBox, VBox
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

# %%
freq_slider = widgets.FloatSlider(
    value=1.5,
    min=1.0,
    max=10.0,
    step=0.1,
    description='Frequency:',
    readout_format='.1f',
)
freq_slider
# Out:
# FloatSlider(value=1.5, description='Frequency:', max=10.0, min=1.0, readout_format='.1f')

# %%
range_slider = widgets.FloatRangeSlider(
    value=[-1., +1.],
    min=-5., max=+5., step=0.1,
    description='xlimit:',
    readout_format='.1f',
)
range_slider
# Out:
# FloatRangeSlider(value=(-1.0, 1.0), description='xlimit:', max=5.0, min=-5.0, readout_format='.1f')

# %%
grid_button = widgets.ToggleButton(
    value=True,
    description='Grid',
    icon='check'
)
grid_button
# Out:
# ToggleButton(value=True, description='Grid', icon='check')

# %%
color_buttons = widgets.ToggleButtons(
    options=['blue', 'red', 'green'],
    description='Color:',
)
color_buttons
# Out:
# ToggleButtons(description='Color:', options=('blue', 'red', 'green'), value='blue')

# %%
title_textbox = widgets.Text(
    value='Hello World',
    description='Title:',
)
title_textbox
# Out:
# Text(value='Hello World', description='Title:')

# %%
color_picker = widgets.ColorPicker(
    concise=True,
    description='Background color:',
    value='#efefef',
)
color_picker
# Out:
# ColorPicker(value='#efefef', concise=True, description='Background color:')

# %%
button = widgets.Button(
    description='Plot',
)
button
# Out:
# Button(description='Plot', style=ButtonStyle())

# %%
#Check Edureka blog in Module 9 for GUI programming using TKinter in Python

# %%
button.on_click
def plot_on_click(b):
    plot2()

# %%
def plot2(b=None):
    xlim = range_slider.value
    freq = freq_slider.value
    grid = grid_button.value
    color = color_buttons.value
    title = title_textbox.value
    bgcolor = color_picker.value

    t = np.linspace(xlim[0], xlim[1], 1000)
    f, ax = plt.subplots(1, 1, figsize=(8, 6))
    ax.plot(t, np.sin(2 * np.pi * freq * t),
            color=color)
    ax.set_facecolor(bgcolor)
    ax.grid(grid)

# %%
button
# Out:
# Button(description='Plot', style=ButtonStyle())

# %%
@button.on_click
def plot_on_click(b):
    plot2()

# %%
plt.plot()
# Out:
# []

# %%
tab1 = VBox(children=[freq_slider, range_slider])
tab2= VBox(children=[color_buttons,
                    HBox(children=[title_textbox,
                                   color_picker, 
                                   grid_button]),
                                   ])
tab1
# Out:
# VBox(children=(FloatSlider(value=1.0, description='Frequency:', max=10.0, min=1.0, readout_format='.1f'), Floa…

# %%
tab = widgets.Tab(children=[tab1, tab2])
tab.set_title(0, 'plot')
tab.set_title(1, 'styling')
VBox(children=[tab, button])
# Out:
# VBox(children=(Tab(children=(VBox(children=(FloatSlider(value=1.0, description='Frequency:', max=10.0, min=1.0…
